# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import time

# %%
# 如果是linux系统
trainPath = os.getcwd()+'/train.csv'
testPath = os.getcwd()+'/test.csv'
train_df = pd.read_csv(trainPath, index_col=0)
test_df = pd.read_csv(testPath,)
# Out:
# /Users/xhxt2008/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Path1 = os.getcwd()+'/LoanStats3a.csv'
Path2 = os.getcwd()+'/LoanStats3b.csv'
Path3 = os.getcwd()+'/LoanStats3c.csv'
Path4 = os.getcwd()+'/LoanStats3d.csv'
LoanStats_df1 = pd.read_csv(Path1)
LoanStats_df2 = pd.read_csv(Path2)
LoanStats_df3 = pd.read_csv(Path3)
LoanStats_df4 = pd.read_csv(Path4)
# Out:
# /Users/xhxt2008/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/xhxt2008/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0,47,123,124,125,128,129,130,133) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/xhxt2008/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/xhxt2008/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0,19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
LoanStats_df = pd.concat((LoanStats_df1, LoanStats_df2,LoanStats_df3,LoanStats_df4),ignore_index=True, axis = 0)

# %%
#LoanStats_data = LoanStats_df.loc[:,['acc_now_delinq','revol_bal','zip_code','int_rate','total_pymnt']]

# %%
idx = LoanStats_df['zip_code']+LoanStats_df['addr_state'] +LoanStats_df['emp_title'].astype('string')+LoanStats_df['annual_inc'].astype('string')+LoanStats_df['revol_bal'].astype('string')

# %%
idx2 = test_df['zip_code']+test_df['addr_state'] +test_df['emp_title'].astype('string')+test_df['annual_inc'].astype('string')+test_df['revol_bal'].astype('string')

# %%
LoanStats_df.isnull().sum().sort_values(ascending=True)
# Out:
# idx                                               19
# hardship_flag                                     19
# zip_code                                          19
# addr_state                                        19
# application_type                                  19
# policy_code                                       19
# last_pymnt_amnt                                   19
# collection_recovery_fee                           19
# recoveries                                        19
# total_rec_late_fee                                19
# total_rec_int                                     19
# revol_bal                                         19
# total_rec_prncp                                   19
# total_pymnt_inv                                   19
# initial_list_status                               19
# out_prncp                                         19
# purpose                                           19
# out_prncp_inv                                     19
# total_pymnt                                       19
# pymnt_plan                                        19
# debt_settlement_flag                              19
# loan_amnt                                         19
# funded_amnt                                       19
# funded_amnt_inv                                   19
# term                                              19
# int_rate                                          19
# installment                                       19
# grade                                             19
# sub_grade                                         19
# emp_length                                        19
#                                                ...
# hardship_end_date                             884882
# hardship_start_date                           884882
# hardship_amount                               884882
# deferral_term                                 884882
# hardship_status                               884882
# hardship_reason                               884882
# hardship_type                                 884882
# hardship_length                               884882
# hardship_loan_status                          884882
# hardship_payoff_balance_amount                884882
# hardship_last_payment_amount                  884882
# hardship_dpd                                  884882
# orig_projected_additional_accrued_interest    885344
# verification_status_joint                     886948
# annual_inc_joint                              886948
# dti_joint                                     886950
# id                                            887450
# sec_app_chargeoff_within_12_mths              887459
# sec_app_num_rev_accts                         887459
# sec_app_open_act_il                           887459
# sec_app_revol_util                            887459
# url                                           887459
# member_id                                     887459
# sec_app_open_acc                              887459
# sec_app_mort_acc                              887459
# sec_app_inq_last_6mths                        887459
# sec_app_earliest_cr_line                      887459
# revol_bal_joint                               887459
# sec_app_mths_since_last_major_derog           887459
# sec_app_collections_12_mths_ex_med            887459
# Length: 146, dtype: int64

# %%
idx.describe()
# Out:
# count               887440
# unique              887283
# top       100xxNYnannan0.0
test_df['idx']=idx2

# %%
LoanStats_df.index
# Out:
# RangeIndex(start=0, stop=887459, step=1)

# %%
LoanStats_df.idx.describe()
# Out:
# count               887440
# unique              887283
# top       100xxNYnannan0.0
# freq                     4
# Name: idx, dtype: object

# %%
LoanStats_df.idx
# Out:
# 0                                  860xxAZnan24000.013648.0
# 1                                 309xxGARyder30000.01687.0
# 2                                   606xxILnan12252.02956.0
# 3                   917xxCAAIR RESOURCES BOARD49200.05598.0
# 4             972xxORUniversity Medical Group80000.027783.0
# 5                  852xxAZVeolia Transportaton36000.07963.0
# 6            280xxNCSouthern Star Photography47004.017726.0
# 7                       900xxCAMKC Accounting 48000.08221.0
# 8                                   958xxCAnan40000.05210.0
# 9                             774xxTXStarbucks15000.09279.0
# 10                853xxAZSouthwest Rural metro72000.04032.0
# 11                                913xxCAUCLA75000.023336.0
# 12        245xxVAVa. Dept of Conservation/Recreation3000...
# 13                               606xxILTarget15000.07323.0
# 14                              951xxCASFMTA100000.011997.0
# 15             641xxMOInternal revenue Service28000.06524.0
# 16                   921xxCAChin's Restaurant42000.024043.0
# 17                           067xxCTDuracell110000.022836.0
# 18                   890xxUTConnection Inspection84000.00.0
# 19        921xxCANetwork Interpreting Service77385.197314.0
# 20        770xxTXArchdiocese of Galveston Houston43370.0...
# 21                     335xxFLOsram Sylvania105000.032135.0
# 22                           799xxTXValue Air50000.010056.0
# 23                    917xxCAWells Fargo Bank50000.017800.0
# 24                      900xxCAbmg-educational76000.05963.0
# 25        605xxILWinfield Pathology Consultants92000.013...
# 26                          103xxNYnyc transit60000.05872.0
# 27                            150xxPAFrito Lay50004.04345.0
# 28        326xxFLShands Hospital at the University of Fl...
# 29                       564xxMNOakridge homes25000.06441.0
#                                 ...
# 887429                 412xxKYField Supervisor52000.07710.0
# 887430                         308xxGAOperator90000.06707.0
# 887431                             840xxUTnan54000.032167.0
# 887432                339xxFLVP of Operations57000.014848.0
# 887433         597xxMTAssistant Maint Manager50000.041546.0
# 887434                          282xxNCOwner103000.017275.0
# 887435                             550xxMNnan55000.013860.0
# 887436                138xxNYBusiness Manager92000.075645.0
# 887437                        021xxMADirector65000.023356.0
# 887438                         871xxNMSr. Tech50000.04611.0
# 887439                   333xxFLArea Director75000.010529.0
# 887440              471xxINmachining Cell Lead57000.02684.0
# 887441             325xxFLCoordinator of RSVP54000.010776.0
# 887442                        891xxNVBartender40000.08731.0
# 887443                       286xxNCTeam Leader30000.0672.0
# 887444                          330xxFLPainter27000.01756.0
# 887445                  956xxCALead Custodian 50000.01700.0
# 887446                              430xxOHnan32000.06987.0
# 887447                            531xxWIOwner40000.06361.0
# 887448                         791xxTXManager25400.018266.0
# 887449            432xxOHKYC Business Analyst63000.021110.0
# 887450          072xxNJDirector of Maintenance79000.08621.0
# 887451                905xxCAOffice Assistant31000.014037.0
# 887452                          010xxMAPainter64400.08254.0
# 887453        378xxTNRadiologist Technologist35000.011031.0
# 887454    331xxFLManager Hotel Operations Oasis 100000.0...
# 887455                                                  NaN
# 887456                                                  NaN
# 887457                                                  NaN
# 887458                                                  NaN
# Name: idx, Length: 887459, dtype: object

# %%
LoanStats_df.zip_code
# Out:
# 0         860xx
# 1         309xx
# 2         606xx
# 3         917xx
# 4         972xx
# 5         852xx
# 6         280xx
# 7         900xx
# 8         958xx
# 9         774xx
# 10        853xx
# 11        913xx
# 12        245xx
# 13        606xx
# 14        951xx
# 15        641xx
# 16        921xx
# 17        067xx
# 18        890xx
# 19        921xx
# 20        770xx
# 21        335xx
# 22        799xx
# 23        917xx
# 24        900xx
# 25        605xx
# 26        103xx
# 27        150xx
# 28        326xx
# 29        564xx
#           ...
# 887429    412xx
# 887430    308xx
# 887431    840xx
# 887432    339xx
# 887433    597xx
# 887434    282xx
# 887435    550xx
# 887436    138xx
# 887437    021xx
# 887438    871xx
# 887439    333xx
# 887440    471xx
# 887441    325xx
# 887442    891xx
# 887443    286xx
# 887444    330xx
# 887445    956xx
# 887446    430xx
# 887447    531xx
# 887448    791xx
# 887449    432xx
# 887450    072xx
# 887451    905xx
# 887452    010xx
# 887453    378xx
# 887454    331xx
# 887455      NaN
# 887456      NaN
# 887457      NaN
# 887458      NaN
# Name: zip_code, Length: 887459, dtype: object

# %%
test_df.shape
# Out:
# (177476, 64)

# %%
LoanStats_new = LoanStats_df.loc[:,['acc_now_delinq','idx']]

# %%
LoanStats_new.shape
# Out:
# (887286, 2)

# %%
test_df.shape
# Out:
# (177476, 64)

# %%
LoanStats_new = LoanStats_new.drop_duplicates(subset='idx')

# %%
LoanStats_new.idx.describe()
# Out:
# count                                                887283
# unique                                               887283
# top       850xxAZPlanning Administration Manager71500.01...
# freq                                                      1
# Name: idx, dtype: object

# %%
LoanStats_new.shape
# Out:
# (887459, 2)

# %%
test_new1 = test_df.join(LoanStats_new.set_index('idx'), on='idx')

# %%
test_new = pd.merge(test_df,LoanStats_new,left_on='idx',right_on='idx')

# %%
test_new1.acc_now_delinq.isnull().sum()
# Out:
# 0

# %%
test_new1.shape
# Out:
# (177476, 65)

# %%
test_new1.acc_now_delinq=test_new1.acc_now_delinq.fillna(0)

# %%
test_new1.loc[:,['zip_code','idx']]
# Out:
#        zip_code                                                idx
# 0         458xx                     458xxOHCustodian42000.013949.0
# 1         287xx                      287xxNCPresident40000.05538.0
# 2         443xx                           443xxOHCPA89000.014206.0
# 3         937xx                          937xxCAFCEOC75600.09769.0
# 4         117xx                        117xxNYPlumber25000.09649.0
# 5         606xx              606xxILFunction Chemist70000.019957.0
# 6         606xx             606xxILOperations Manager 45000.0497.0
# 7         548xx                            548xxWIRLSD40000.0268.0
# 8         330xx   330xxFLNew Business & Sales Manager50000.04576.0
# 9         605xx             605xxILRegistered Nurse108000.034601.0
# 10        921xx              921xxCASystems Engineer95000.033102.0
# 11        117xx                     117xxNYCablevision40000.0193.0
# 12        761xx            761xxTXFinance Coordinator44000.07814.0
# 13        376xx         376xxTNChris Mullins Company36000.015837.0
# 14        917xx  917xxCACivil Engineering Associate135000.033320.0
# 15        368xx                           368xxALnan60000.087519.0
# 16        775xx               775xxTXbrazoria county 30809.09936.0
# 17        549xx         549xxWIAffinity Health Sytem78000.012587.0
# 18        336xx                        336xxFLAuditor55273.05087.0
# 19        010xx         010xxMAUltrasound Technician66819.010201.0
# 20        078xx                078xxNJSystem Engineer81000.09764.0
# 21        922xx                          922xxCAsales74000.07354.0
# 22        770xx                 770xxTXCharge nurse 80000.017029.0
# 23        926xx     926xxCATechnical Support Manager60000.014693.0
# 24        283xx            283xxNCwear house stocker40000.010415.0
# 25        351xx            351xxALequipment operator81000.017601.0
# 26        895xx           895xxNVPricing Specialist128000.018749.0
# 27        407xx                       407xxKYTherapist32910.8152.0
# 28        724xx                    724xxARm c express34000.02549.0
# 29        856xx           856xxAZOPERATIONS MANAGER105000.050392.0
# ...         ...                                                ...
# 177446    336xx         336xxFLtractor trailer driver46000.02820.0
# 177447    957xx  957xxCAAssociate Information System Analyst550...
# 177448    163xx                163xxPAManaging editor70000.06956.0
# 177449    804xx                804xxCOPolice Officer110000.08571.0
# 177450    350xx      350xxALTalladega County Schools 55000.02560.0
# 177451    156xx                     156xxPAproduction32000.04177.0
# 177452    440xx                          440xxOHnan125000.011326.0
# 177453    130xx                           130xxNYnan50000.016384.0
# 177454    986xx                            986xxWAnan30000.03107.0
# 177455    255xx                255xxWVDETACHMENT SGT75000.017189.0
# 177456    781xx            781xxTXProduce Specialist75000.029838.0
# 177457    664xx           664xxKSKanza Mental Health45000.011001.0
# 177458    932xx             932xxCAUnited States Navy58000.09708.0
# 177459    981xx               981xxWASales Executive97800.046009.0
# 177460    553xx         553xxMNManager Maintenance 101000.029237.0
# 177461    468xx          468xxINProduction Supervisor85000.04466.0
# 177462    275xx           275xxNCRockwell Automation97000.013997.0
# 177463    104xx          104xxNYCUNY Office Assistant32000.05193.0
# 177464    197xx                           197xxDEnan28000.035964.0
# 177465    391xx                    391xxMSAdministrator54000.067.0
# 177466    768xx  768xxTXAdult Protective Services Investigator5...
# 177467    336xx                        336xxFLowner129000.021499.0
# 177468    228xx                    228xxVAAdmin Asst46500.011372.0
# 177469    917xx                     917xxCASupervisor97000.06372.0
# 177470    752xx                 752xxTXhome inspector78000.05333.0
# 177471    462xx        462xxINDirector of EDucation115000.010558.0
# 177472    949xx    949xxCAFlatiron Construction Corp85000.014993.0
# 177473    773xx                           773xxTXnan53200.020859.0
# 177474    104xx                 104xxNYsuperintendent31200.06518.0
# 177475    750xx             750xxTXAvis budget group69000.020685.0
#
# [177476 rows x 2 columns]

# %%
test_df.issue_d.unique()
# Out:
# array(['Aug-2014', 'Nov-2015', 'Dec-2015', 'Jun-2012', 'Jul-2015',
#        'Aug-2013', 'Jun-2015', 'Oct-2015', 'Nov-2009', 'Jan-2015',
#        'Jul-2013', 'Aug-2012', 'Jun-2013', 'Mar-2014', 'Apr-2014',
#        'Jul-2014', 'Mar-2015', 'Jun-2014', 'Aug-2015', 'Oct-2013',
#        'Oct-2014', 'Nov-2014', 'Sep-2012', 'Sep-2015', 'Oct-2010',
#        'May-2014', 'May-2015', 'Feb-2013', 'Feb-2015', 'Nov-2012',
#        'Dec-2013', 'Feb-2012', 'Apr-2011', 'Apr-2012', 'Sep-2011',
#        'Jan-2014', 'Apr-2015', 'Apr-2013', 'Dec-2014', 'Sep-2013',
#        'Dec-2012', 'Jun-2008', 'Sep-2014', 'Feb-2014', 'Nov-2013',
#        'Oct-2012', 'Dec-2011', 'May-2013', 'Sep-2010', 'Oct-2011',
#        'Dec-2009', 'Jan-2013', 'Mar-2013', 'Jun-2010', 'Jul-2010',
#        'Aug-2009', 'May-2011', 'Nov-2011', 'Feb-2011', 'Jan-2011',
#        'Sep-2009', 'May-2012', 'Mar-2012', 'Oct-2009', 'Feb-2009',
#        'Apr-2010', 'Jun-2011', 'Mar-2011', 'Jul-2011', 'Jan-2012',
#        'Jan-2008', 'Jul-2012', 'Dec-2007', 'Jan-2010', 'Aug-2010',
#        'Nov-2010', 'Mar-2010', 'Feb-2010', 'Mar-2009', 'May-2010',
#        'Dec-2010', 'Apr-2009', 'May-2008', 'Apr-2008', 'Jul-2009',
#        'Aug-2011', 'Feb-2008', 'Jan-2009', 'Sep-2007', 'Aug-2008',
#        'Mar-2008', 'May-2009', 'Oct-2008', 'Jun-2009', 'Jul-2008',
#        'Nov-2008', 'Nov-2007', 'Sep-2008', 'Dec-2008', 'Aug-2007',
#        'Oct-2007', 'Jun-2007', 'Jul-2007'], dtype=object)

# %%
test_new.acc_now_delinq.sum()
# Out:
# 884.0

# %%
test_new.member_id.astype('string').describe()
# Out:
# count     177464
# unique    177463
# top        73096
# freq           2
# Name: member_id, dtype: object

# %%
test_df.shape
# Out:
# (177476, 63)

# %%
isDuplicated = test_new.duplicated()

# %%
isDuplicated.describe()
# Out:
# count     177464
# unique         1
# top        False
# freq      177464
# dtype: object

# %%
test_new1.shape
# Out:
# (177476, 65)

# %%
test_new1.to_csv("test_final.csv" , encoding = "utf-8")

# %%
isDuplicated = test_new.duplicated()

# %%
test_new_bak = test_new.copy()

# %%
tet = test_new.drop_duplicates()

# %%
tet.shape
# Out:
# (177464, 65)

# %%
tp_2 = pd.DataFrame()
for i in range(len(test_df['zip_code'])):
    tp1=tp[tp['zip_code']==test_df['zip_code'][i]]
    tp_2.append(tp1, ignore_index=True)

# %%
tp_3 = pd.DataFrame()
for i in range(len(test_df['int_rate'])):
    tp1=tp[tp['int_rate']==test_df['int_rate'][i]]
    tp_3.append(tp1, ignore_index=True)

# %%
tp1.append(tp1, ignore_index=True)
# Out:
#     acc_now_delinq  revol_bal zip_code int_rate   total_pymnt
# 0              0.0    20685.0    366xx   10.75%  14092.539950
# 1              0.0    20685.0    432xx   13.92%   9156.487756
# 2              0.0    20685.0    222xx   18.54%   3200.391093
# 3              0.0    20685.0    271xx    7.62%  16574.000000
# 4              0.0    20685.0    750xx   14.33%  14411.792150
# 5              0.0    20685.0    853xx   17.58%  38817.329930
# 6              0.0    20685.0    986xx   18.99%  30944.700120
# 7              0.0    20685.0    349xx   23.43%   6087.260000
# 8              0.0    20685.0    863xx   16.99%  23041.040000
# 9              0.0    20685.0    016xx    8.39%  22517.750000
# 10             0.0    20685.0    656xx   18.25%  17153.072960
# 11             0.0    20685.0    601xx   16.55%  11811.370000
# 12             0.0    20685.0    462xx   12.69%  17395.400000
# 13             0.0    20685.0    982xx   12.29%  16902.666840
# 14             0.0    20685.0    601xx   13.66%  13624.250000
# 15             0.0    20685.0    366xx   10.75%  14092.539950
# 16             0.0    20685.0    432xx   13.92%   9156.487756
# 17             0.0    20685.0    222xx   18.54%   3200.391093
# 18             0.0    20685.0    271xx    7.62%  16574.000000
# 19             0.0    20685.0    750xx   14.33%  14411.792150
# 20             0.0    20685.0    853xx   17.58%  38817.329930
# 21             0.0    20685.0    986xx   18.99%  30944.700120
# 22             0.0    20685.0    349xx   23.43%   6087.260000
# 23             0.0    20685.0    863xx   16.99%  23041.040000
# 24             0.0    20685.0    016xx    8.39%  22517.750000
# 25             0.0    20685.0    656xx   18.25%  17153.072960
# 26             0.0    20685.0    601xx   16.55%  11811.370000
# 27             0.0    20685.0    462xx   12.69%  17395.400000
# 28             0.0    20685.0    982xx   12.29%  16902.666840
# 29             0.0    20685.0    601xx   13.66%  13624.250000

# %%
td1=train_df[train_df['acc_now_delinq'] == 1].groupby(['loan_status', 'acc_now_delinq']).size()

# %%
td2=train_df[train_df['acc_now_delinq'] == 0].groupby(['loan_status', 'acc_now_delinq']).size()

# %%
value=[ 130, 2538,    5,    0,    3,  463,   25,   32,   17,   80]

# %%
index=td2.index

# %%
td1=pd.Series(value, index=index)

# %%
td2,td1
# Out:
# (loan_status                                          acc_now_delinq
#  Charged Off                                          0                  36038
#  Current                                              0                 478718
#  Default                                              0                    953
#  Does not meet the credit policy. Status:Charged Off  0                    597
#  Does not meet the credit policy. Status:Fully Paid   0                   1599
#  Fully Paid                                           0                 165889
#  In Grace Period                                      0                   5022
#  Issued                                               0                   6707
#  Late (16-30 days)                                    0                   1874
#  Late (31-120 days)                                   0                   9213
#  dtype: int64,
#  loan_status                                          acc_now_delinq
#  Charged Off                                          0                  130
#  Current                                              0                 2538
#  Default                                              0                    5
#  Does not meet the credit policy. Status:Charged Off  0                    0
#  Does not meet the credit policy. Status:Fully Paid   0                    3
#  Fully Paid                                           0                  463
#  In Grace Period                                      0                   25
#  Issued                                               0                   32
#  Late (16-30 days)                                    0                   17
#  Late (31-120 days)                                   0                   80
#  dtype: int64)

# %%
a = td2.values
b = td1.values.astype(float)

values= b/a

# %%
values
# Out:
# array([ 0.0036073 ,  0.00530166,  0.00524659,  0.        ,  0.00187617,
#         0.00279102,  0.0049781 ,  0.00477113,  0.0090715 ,  0.00868338])

# %%
td3=pd.Series(values, index=index)

# %%
td3
# Out:
# loan_status                                          acc_now_delinq
# Charged Off                                          0                 0.003607
# Current                                              0                 0.005302
# Default                                              0                 0.005247
# Does not meet the credit policy. Status:Charged Off  0                 0.000000
# Does not meet the credit policy. Status:Fully Paid   0                 0.001876
# Fully Paid                                           0                 0.002791
# In Grace Period                                      0                 0.004978
# Issued                                               0                 0.004771
# Late (16-30 days)                                    0                 0.009072
# Late (31-120 days)                                   0                 0.008683
# dtype: float64

# %%
import seaborn as sns
# palette = ["#3791D7", "#E01E1B"]
# ax1 = sns.countplot(x='acc_now_delinq', data=train_df, 
#                   palette=palette, hue='term')
# ax1= plt.subplots(nrows=2, ncols=2, figsize=(14,6))
# ax1.set_title('The impact of maturity date \n on interest rates', fontsize=14)
# ax1.set_xlabel('acc_now_delinq', fontsize=12)
# ax1.set_ylabel('loan_status')

# sns.violinplot(x="acc_now_delinq", y="loan_status", data=train_df, palette="Set2", ax=ax1 )


fig, ax1= plt.subplots(nrows=1, ncols=1, figsize=(14,6))
cmap = plt.cm.coolwarm_r
# Change the Palette types tomorrow!

# sns.barplot(x="loan_status", y="acc_now_delinq", data=train_df1, palette="Set2", ax=ax1 )
# sns.violinplot(x="income_category", y="loan_condition_int", data=df, palette="Set2", ax=ax2)
# sns.boxplot(x="income_category", y="emp_length_int", data=df, palette="Set2", ax=ax3)
# sns.boxplot(x="income_category", y="interest_rate", data=df, palette="Set2", ax=ax4)
#loans_by_region = td3.groupby(['loan_status', 'acc_now_delinq']).size()
td3.unstack().plot(kind='bar', stacked=True, colormap=cmap, ax=ax1, grid=False)
ax1.set_title('Type of Loans by Grade', fontsize=14)

# %%
plt.show()

# %%
# 如果是win系统

#train_df = pd.read_csv('train.csv', index_col=0)
#test_df = pd.read_csv('test.csv', index_col=0)

# %%
#去除y值
y_train = train_df.pop('acc_now_delinq')

# %%
#合并训练、测试集
all_df = pd.concat((train_df, test_df), axis = 0)

# %%
data = all_df

# %%
original_df = all_df.copy()

# %%
all_df.columns.values
# Out:
# array(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'earliest_cr_line', 'mths_since_last_record',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'tot_coll_amt', 'tot_cur_bal',
#        'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m',
#        'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m',
#        'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim',
#        'inq_fi', 'total_cu_tl', 'inq_last_12m'], dtype=object)

# %%
data = original_df

# %%
# 贷款状态只保留good 和bad: loan_status->loan_condition
bad_loan = ["Charged Off", "Default", "Does not meet the credit policy. Status:Charged Off", "In Grace Period", 
            "Late (16-30 days)", "Late (31-120 days)"]


data['loan_condition'] = np.nan

def loan_condition(status):
    if status in bad_loan:
        return 'Bad Loan'
    else:
        return 'Good Loan'
    
    
data['loan_condition'] = data['loan_status'].apply(loan_condition)

# %%
#  地域划分addr_state->region
west = ['CA', 'OR', 'UT','WA', 'CO', 'NV', 'AK', 'MT', 'HI', 'WY', 'ID']
south_west = ['AZ', 'TX', 'NM', 'OK']
south_east = ['GA', 'NC', 'VA', 'FL', 'KY', 'SC', 'LA', 'AL', 'WV', 'DC', 'AR', 'DE', 'MS', 'TN' ]
mid_west = ['IL', 'MO', 'MN', 'OH', 'WI', 'KS', 'MI', 'SD', 'IA', 'NE', 'IN', 'ND']
north_east = ['CT', 'NY', 'PA', 'NJ', 'RI','MA', 'MD', 'VT', 'NH', 'ME']

data['region'] = np.nan

def finding_regions(state):
    if state in west:
        return 'West'
    elif state in south_west:
        return 'SouthWest'
    elif state in south_east:
        return 'SouthEast'
    elif state in mid_west:
        return 'MidWest'
    elif state in north_east:
        return 'NorthEast'
    
data['region'] = data['addr_state'].apply(finding_regions)

# %%
#sub_grade

sub_grade_mapping = {'A1':0,'A2':1,'A3':2,'A4':3,'A5':4,
                     'B1':5,'B2':6,'B3':7,'B4':8,'B5':9,
                     'C1':10,'C2':11,'C3':12,'C4':13,'C5':14,
                     'D1':15,'D2':16,'D3':17,'D4':18,'D5':19,
                     'E1':20,'E2':21,'E3':22,'E4':23,'E5':24,
                     'F1':25,'F2':26,'F3':27,'F4':28,'F5':29,
                     'G1':30,'G2':31,'G3':32,'G4':33,'G5':34}

data.sub_grade = data.sub_grade.map(sub_grade_mapping)

# %%
data.issue_d = pd.to_datetime(data['issue_d'])
data.earliest_cr_line = pd.to_datetime(data['earliest_cr_line'])

# %%
data['issue_d_year']=data.issue_d.dt.year
data['issue_d_month'] = data.issue_d.dt.month
data['earliest_cr_line_year']=data.earliest_cr_line.dt.year
data['earliest_cr_line_month'] = data.earliest_cr_line.dt.month

# %% [markdown]
# ## 要删除的

# %%
'''
for delete: grade,zip_code,inq_last_12m,total_cu_tl,open_acc_6m,open_il_12m,open_il_24m,open_il_6m,total_bal_il,
open_rv_12m,open_rv_24m,max_bal_bc,all_util,inq_fi,policy_code,emp_title,emp_title,desc,title,zip_code,dti_joint,
annual_inc_joint,varification_status_joint,il_uti,mths_since_last_record,mths_since_last_major_derog,addr_state,
issue_d,earliest_cr_line
新增：loan_status,addr_state
'''
feature_delete = {'grade','zip_code','inq_last_12m','total_cu_tl','open_acc_6m','open_il_12m','open_il_24m',
                  'open_il_6m','total_bal_il','open_rv_24m','open_rv_12m','max_bal_bc','all_util','inq_fi',
                 'emp_title','policy_code','desc','title','dti_joint','annual_inc_joint','addr_state','mths_since_rcnt_il',
                 'verification_status_joint','il_util','mths_since_last_record','mths_since_last_major_derog',
                  'issue_d','earliest_cr_line','loan_status','addr_state'}
data = data.drop(feature_delete,axis=1)

# %% [markdown]
# ## 二值化

# %%
#for binarilization：pymnt_plan,term, application_type, initial_list_status
feature_for_binary = {'term','pymnt_plan','application_type','initial_list_status'}
def binary(feature_for_binary,data):
    for items in feature_for_binary: 
        mapping = {label:idx for idx,label in enumerate(set(data[items]))}  
        data[items] = data[items].map(mapping) 
    return data

# %%
binary(feature_for_binary,data)
temp = data.copy()

# %%
#emp_length 不再需要fillna！
emp_length_mapping = {'10+ years':10,'9 years':9,'8 years':8,'7 years':7,'6 years':6,
                       '5 years':5,'4 years':4,'3 years':3,'2 years':2,'1 year':1,'< 1 year':0.5,'n/a':0}
data.emp_length = data.emp_length.map(emp_length_mapping)

# %% [markdown]
# ## 填充null值

# %%
'''
少量null值的处理，用均值替代：emp_length, revol_util, annual_inc, total_acc, earliest_cr_line, tot_cur_bal, tot_coll_amt
total_rev_hi_lim, revol_util, pub_rec, collections_12_mths_ex_med
'''
feature_fill_null = {'emp_length','revol_util','annual_inc','total_acc','earliest_cr_line_year','earliest_cr_line_month','tot_cur_bal',
                    'tot_coll_amt','total_rev_hi_lim','revol_util','pub_rec','collections_12_mths_ex_med'}
def fill_null(feature_fill_null,data):
    for items in feature_fill_null:
        try:
            time.strptime(data[items].mode()[0],"%b-%Y")
            data[items] = data[items].fillna(data[items].mode()[0])
            print (data[items].mode()[0])
#            print ('yes')
        except:
            data[items] = data[items].fillna(data[items].mean())
            print (data[items].mean())
#            print('no')
#         if time.strptime(feature_dropna.mode()[0],"%b-%Y"):
#             data[items] = data[items].fillna(feature_dropna.mode())
#             print feature_dropna.mode()
#         else:
#             data[items] = data[items].fillna(feature_dropna.mean())
    return data

# %%
fill_null(feature_fill_null,data)
# Out:
# 6.75610976503
# 139458.189336
# 55.0676932314
# 225.702610319
# 75027.5877608
# 1997.70018144
# 25.2680261453
# 32068.6200454
# 6.00869499165
# 0.0143795210734
# 0.195307375895
#            loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate
# 54209112     31200.0      31200.0          31200.0     1     22.99
# 4150401      14125.0      14125.0          14125.0     0      7.90
# 1823353      21250.0      21250.0          21250.0     0     14.09
# 44164218     10000.0      10000.0          10000.0     0     12.29
# 1765507      12000.0      12000.0          12000.0     0     14.33
#
#            installment  sub_grade  emp_length home_ownership  annual_inc  \
# member_id
# 13599771        321.97         17    8.000000       MORTGAGE     55000.0
# 1491956         396.92          4    1.000000       MORTGAGE     43000.0
# 64687987        863.31         21    9.000000           RENT    101300.0
# 8446850         358.78          5   10.000000       MORTGAGE     47840.0
# 58471388        347.87         17    5.000000           RENT     30000.0
# 5337525         599.96         14   10.000000            OWN     70000.0
# 30165519        293.67         16    1.000000       MORTGAGE     40000.0
# 1909391         624.35         20    4.000000       MORTGAGE    110000.0
# 43182363        322.34          7    3.000000       MORTGAGE    100000.0
# 69222001        438.64         12   10.000000           RENT     77000.0
# 16540530        112.94          7    7.000000            OWN     42000.0
# 71160396        443.01         16    8.000000           RENT     40000.0
# 60071842       1094.77         16   10.000000       MORTGAGE     61800.0
# 57668328        275.07         12    3.000000       MORTGAGE     52000.0
# 67687466        184.97          2    3.000000           RENT     46000.0
# 15369372        700.05          1    4.000000       MORTGAGE    109100.0
# 43835646        136.70         13    5.000000           RENT     86564.0
# 779496          315.67          2   10.000000       MORTGAGE    135000.0
# 61616912        725.79          9   10.000000            OWN     50000.0
# 70236564        782.15          4    2.000000            OWN    100000.0
# 15049437        404.61         22   10.000000           RENT     60000.0
# 6827555         367.09         13    8.000000       MORTGAGE    110000.0
# 11918997        477.97         16    7.000000       MORTGAGE    117000.0
# 2830469        1126.35         11    2.000000           RENT     72000.0
# 34952648        501.24          6    6.008695            OWN    107000.0
# 42586279        229.12         24   10.000000           RENT     35000.0
# 48602144        456.39         23    2.000000       MORTGAGE     47500.0
# 60214560        327.43          9    4.000000       MORTGAGE     43000.0
# 7430576         524.38         14   10.000000           RENT     48230.0
# 43081898        759.18         15    3.000000           RENT     85000.0
# ...                ...        ...         ...            ...         ...
# 66393012        566.85         20    0.000000            OWN     46000.0
# 9339706         279.41         13    2.000000       MORTGAGE     55000.0
# 26427450        296.47         10    4.000000           RENT     70000.0
# 48412828        483.94          7    9.000000       MORTGAGE    110000.0
# 7641212         115.26         26    1.000000       MORTGAGE     55000.0
# 35893585         78.68         15   10.000000       MORTGAGE     32000.0
# 31606789        543.44          7   10.000000       MORTGAGE    125000.0
# 25826363        327.34          7    6.008695           RENT     50000.0
# 23044013        123.01         12    6.008695           RENT     30000.0
# 18565259        581.45         12   10.000000           RENT     75000.0
# 70226493        950.94          7    4.000000       MORTGAGE     75000.0
# 7422113         330.00          7    4.000000       MORTGAGE     45000.0
# 1725105         171.78         14    8.000000           RENT     58000.0
# 13689178        762.08          4    1.000000       MORTGAGE     97800.0
# 70410007       1095.00          4   10.000000       MORTGAGE    101000.0
# 34390938        416.82          5    4.000000       MORTGAGE     85000.0
# 1862377         337.47          8    7.000000       MORTGAGE     97000.0
# 62249415        469.42          7    3.000000           RENT     32000.0
# 20116760        261.67         18    6.008695       MORTGAGE     28000.0
# 67778233        600.63         23   10.000000           RENT     54000.0
# 16641826        576.90         22   10.000000       MORTGAGE     51000.0
# 24577209        551.55          4   10.000000           RENT    129000.0
# 47943366        196.07         17    9.000000       MORTGAGE     46500.0
# 42832436         50.11         10    9.000000       MORTGAGE     97000.0
# 63504974        290.37          7    3.000000            OWN     78000.0
# 54209112        879.37         26    0.000000       MORTGAGE    115000.0
# 4150401         441.98          3    4.000000       MORTGAGE     85000.0
# 1823353         727.21          9    4.000000       MORTGAGE     53200.0
# 44164218        333.53         10   10.000000            OWN     31200.0
# 1765507         412.06         10    6.000000       MORTGAGE     69000.0
#
#                     ...           collection_recovery_fee  \
# member_id           ...
# 13599771            ...                          224.7408
# 1491956             ...                            0.0000
# 64687987            ...                            0.0000
# 8446850             ...                            0.0000
# 58471388            ...                            0.0000
# 5337525             ...                            0.0000
# 30165519            ...                            0.0000
# 1909391             ...                          724.1454
# 43182363            ...                            0.0000
# 69222001            ...                            0.0000
# 16540530            ...                            0.0000
# 71160396            ...                            0.0000
# 60071842            ...                            0.0000
# 57668328            ...                            0.0000
# 67687466            ...                            0.0000
# 15369372            ...                            0.0000
# 43835646            ...                            0.0000
# 779496              ...                            0.0000
# 61616912            ...                            0.0000
# 70236564            ...                            0.0000
# 15049437            ...                            0.0000
# 6827555             ...                            0.0000
# 11918997            ...                            0.0000
# 2830469             ...                            0.0000
# 34952648            ...                            0.0000
# 42586279            ...                            0.0000
# 48602144            ...                            0.0000
# 60214560            ...                            0.0000
# 7430576             ...                            0.0000
# 43081898            ...                            0.0000
# ...                 ...                               ...
# 66393012            ...                            0.0000
# 9339706             ...                            0.0000
# 26427450            ...                            0.0000
# 48412828            ...                            0.0000
# 7641212             ...                            0.0000
# 35893585            ...                            0.0000
# 31606789            ...                            0.0000
# 25826363            ...                            0.0000
# 23044013            ...                            0.0000
# 18565259            ...                            0.0000
# 70226493            ...                            0.0000
# 7422113             ...                            0.0000
# 1725105             ...                            0.0000
# 13689178            ...                            0.0000
# 70410007            ...                            0.0000
# 34390938            ...                            0.0000
# 1862377             ...                            0.0000
# 62249415            ...                            0.0000
# 20116760            ...                            0.0000
# 67778233            ...                            0.0000
# 16641826            ...                            0.0000
# 24577209            ...                            0.0000
# 47943366            ...                            0.0000
# 42832436            ...                            0.0000
# 63504974            ...                            0.0000
# 54209112            ...                            0.0000
# 4150401             ...                            0.0000
# 1823353             ...                            0.0000
# 44164218            ...                            0.0000
# 1765507             ...                            0.0000
#
#           collections_12_mths_ex_med  application_type tot_coll_amt  \
# member_id
# 13599771                         0.0                 1      0.00000
# 1491956                          0.0                 1    225.70261
# 64687987                         0.0                 1    770.00000
# 8446850                          0.0                 1    102.00000
# 58471388                         0.0                 1      0.00000
# 5337525                          0.0                 1      0.00000
# 30165519                         0.0                 1   1380.00000
# 1909391                          0.0                 1      0.00000
# 43182363                         0.0                 1      0.00000
# 69222001                         0.0                 1      0.00000
# 16540530                         0.0                 1     69.00000
# 71160396                         0.0                 1      0.00000
# 60071842                         0.0                 1      0.00000
# 57668328                         0.0                 1      0.00000
# 67687466                         0.0                 1      0.00000
# 20116760                  1968.0                     8.0
# 67778233                  1999.0                    10.0
# 16641826                  2002.0                     1.0
# 24577209                  1999.0                     7.0
# 47943366                  1981.0                     6.0
# 42832436                  2000.0                     8.0
# 63504974                  2004.0                     1.0
# 54209112                  1993.0                     4.0
# 4150401                   2008.0                     1.0
# 1823353                   1998.0                    11.0
# 44164218                  2003.0                     8.0
# 1765507                   2002.0                     5.0
#
# [887379 rows x 38 columns]

# %%
#fill null = 0: collections_12_mths_ex_med
data.collections_12_mths_ex_med = data.collections_12_mths_ex_med.fillna(0)

# %%
temp1 = data.copy()

# %% [markdown]
# ## 离散多类型变量

# %%
#for get_dummies: home_ownership, verification_status, loan_status,purpose

feature_for_dummy = {'home_ownership','verification_status','loan_status','purpose'}
def multi_get_dummies(feature_for_dummy,data):
    for items in feature_for_dummy: 
        data = data.join(pd.get_dummies(data[items],prefix=items))
        data.pop(items)
    return data

# %%
loan_status_mapping = {'Charged Off':'CF','Fully Paid':'FP','Current':'Current','In Grace Period':'IGP','Late (31-120 days)':'L31-120',
                       'Issued':'Issued','Does not meet the credit policy. Status:Charged Off':'NotMeetCF','Does not meet the credit policy. Status:Fully Paid':'NotMeetFP',
                       'Default':'Default','Late (16-30 days)':'L16-30'}
data.loan_status = data.loan_status.map(loan_status_mapping)

# %%
data.loan_status.unique()
# Out:
# array(['CF', 'FP', 'Current', 'IGP', 'L31-120', 'Issued', 'NotMeetCF',
#        'NotMeetFP', 'Default', 'L16-30'], dtype=object)

# %%
data = multi_get_dummies(feature_for_dummy,data)

# %%
data.head()
# Out:
#            loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  \
# member_id
# 13599771      8875.0       8875.0           8875.0     0     18.25
# 1491956      12500.0      12500.0          12475.0     0      8.90
# 64687987     33600.0      33600.0          33600.0     1     18.55
# 8446850      17000.0      17000.0          17000.0     1      9.71
# 58471388     14000.0      14000.0          14000.0     1     16.99
#
#            installment  sub_grade  emp_length  annual_inc  pymnt_plan  \
# member_id
# 13599771        321.97         17         8.0     55000.0           1
# 1491956         396.92          4         1.0     43000.0           1
# 64687987        863.31         21         9.0    101300.0           1
# 8446850         358.78          5        10.0     47840.0           1
# 58471388        347.87         17         5.0     30000.0           1
#
#                        ...               purpose_medical  purpose_moving  \
# member_id              ...
# 13599771               ...                             0               0
# 1491956                ...                             0               0
# 64687987               ...                             0               0
# 8446850                ...                             0               0
# 58471388               ...                             0               0
#
#            purpose_other  purpose_renewable_energy  purpose_small_business  \
# member_id
# 13599771               0                         0                       0
# 1491956                0                         0                       0
# 64687987               0                         0                       0
# 8446850                0                         0                       0
# 58471388               0                         0                       0
#
#            purpose_vacation  purpose_wedding  \
# member_id
# 13599771                  0                0
# 1491956                   0                0
# 64687987                  0                0
# 8446850                   0                0
# 58471388                  0                0
#
#            verification_status_Not Verified  \
# member_id
# 13599771                                  0
# 1491956                                   0
# 64687987                                  0
# 8446850                                   0
# 58471388                                  0
#
#            verification_status_Source Verified  verification_status_Verified
# member_id
# 13599771                                     0                             1
# 1491956                                      1                             0
# 64687987                                     1                             0
# 8446850                                      0                             1
# 58471388                                     1                             0
#
# [5 rows x 67 columns]

# %%
data.isnull().sum()
# Out:
# loan_amnt                              0
# funded_amnt                            0
# funded_amnt_inv                        0
# term                                   0
# int_rate                               0
# installment                            0
# sub_grade                              0
# emp_length                             0
# annual_inc                             0
# pymnt_plan                             0
# dti                                    0
# pub_rec                                0
# revol_bal                              0
# revol_util                             0
# total_acc                              0
# initial_list_status                    0
# out_prncp                              0
# out_prncp_inv                          0
# total_pymnt                            0
# total_pymnt_inv                        0
# total_rec_prncp                        0
# total_rec_int                          0
# total_rec_late_fee                     0
# recoveries                             0
# collection_recovery_fee                0
# collections_12_mths_ex_med             0
# application_type                       0
# tot_coll_amt                           0
# tot_cur_bal                            0
# total_rev_hi_lim                       0
#                                       ..
# loan_status_FP                         0
# loan_status_IGP                        0
# loan_status_Issued                     0
# loan_status_L16-30                     0
# loan_status_L31-120                    0
# loan_status_NotMeetCF                  0
# loan_status_NotMeetFP                  0
# home_ownership_ANY                     0
# home_ownership_MORTGAGE                0
# home_ownership_NONE                    0
# home_ownership_OTHER                   0
# home_ownership_OWN                     0
# home_ownership_RENT                    0
# purpose_car                            0
# purpose_credit_card                    0
# purpose_debt_consolidation             0
# purpose_educational                    0
# purpose_home_improvement               0
# purpose_house                          0
# purpose_major_purchase                 0
# purpose_medical                        0
# purpose_moving                         0
# purpose_other                          0
# purpose_renewable_energy               0
# purpose_small_business                 0
# purpose_vacation                       0
# purpose_wedding                        0
# verification_status_Not Verified       0
# verification_status_Source Verified    0
# verification_status_Verified           0
# Length: 67, dtype: int64

# %%
data.shape
# Out:
# (887379, 67)

# %%
processed_train_df = data.loc[train_df.index]
processed_test_df = data.loc[test_df.index]

# %%
processed_train_df.shape
# Out:
# (709903, 67)

# %%
processed_test_df.shape
# Out:
# (177476, 67)

# %%
processed_train_df2 = processed_train_df.join(y_train)

# %%
processed_train_df2.shape
# Out:
# (709903, 68)

# %%
processed_train_df2.to_csv("processed_train.csv" , encoding = "utf-8")
processed_test_df.to_csv("processed_test.csv" , encoding = "utf-8")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2045e0094d2c> in <module>()
# ----> 1 processed_train_df2.to_csv("／processed_train.csv" , encoding = "utf-8")
#       2 processed_test_df.to_csv("／processed_test.csv" , encoding = "utf-8")
#
# NameError: name 'processed_train_df2' is not defined

# %%
from sklearn import cross_validation
# Out:
# /Users/xhxt2008/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
processed_train_df = pd.read_csv(os.getcwd()+'/processed_train.csv', index_col=0)
processed_test_df = pd.read_csv(os.getcwd()+'/processed_train.csv', index_col=0)

# %%
y_train = processed_train_df.pop('acc_now_delinq')

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(processed_train_df, y_train, 
                                                                     test_size=0.37, random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
result = knn.predict(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = ("RandomForestClassifier, max_features='sqrt'",
        RandomForestClassifier(warm_start=True, oob_score=True,
                               max_features="sqrt",n_estimators=100,
                               random_state=123))

# %%
rf[1].fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=True, random_state=123,
#             verbose=0, warm_start=True)

# %%
pre = rf[1].predict(X_test)

# %%
pre.sum()
# Out:
# 0

# %%
data.out_prncp.corr(data.out_prncp_inv)
# Out:
# 0.9999972465636372

# %%
data.sub_grade.skew()
# Out:
# 0.57094469868205833

# %%
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=True, random_state=123,
#             verbose=0, warm_start=True)
